# %% [markdown]
# # Get Settled

# %%
address = 'Almogavers 119'
time = 10
property_type='homes'
min_price = 300
max_price = 900
distance_weight = 5
availability_weight = 3
security_weight = 1
n_neighbourhood = 3

# %%
from Ranking import Ranking

# %%
ranking = Ranking()

# %%
lista = ranking.get_ranking(address=address, time=time, min_price=min_price, max_price=max_price, 
                            distance_weight=distance_weight, availability_weight=availability_weight,
                            security_weight=security_weight,n_neighbourhood=n_neighbourhood, property_type=property_type)
# Out:
# Distance ranking for: Almogavers 119 with distance of 830 meters
# ---------------------------------------
# ---------------------------------------
# Getting circles
# Distance before weight: 830 meters
# Distance after weight: 1310 meters
# Circle at 1310 meters
# Circle at 1010 meters
# Circle at 710 meters
# Circle at 410 meters
# Circle at 110 meters
# Getting circles success
# Adding pizza coordinates
# Adding pizza coordinates success
# ---------------------------------------
# ---------------------------------------
# Distance Ranking:
# ---------------------------------------
# [('El Parc i la Llacuna del Poblenou', 41), ('Fort Pienc', 15), ('La Vila Olímpica del Poblenou', 10), ('El Poblenou', 7), ('S. Pere, Santa Caterina, i la Rib.', 4), ('El Clot', 2), ('Sagrada Familia', 1), ('Provençals de Poblenou', 1)]
#
#
# Availability ranking for propertyType= homes between €300 and €900
# ---------------------------------------
# ---------------------------------------
# Request Idealista page: 1
# Request Idealista page: 1 success
# Request Idealista page: 2
# Request Idealista page: 2 success
# Request Idealista page: 3
# Request Idealista page: 3 success
# Request Idealista page: 4
# Request Idealista page: 4 success
# ---------------------------------------
# ---------------------------------------
# Availability Ranking:
# ---------------------------------------
# [("La Dreta de l'Eixample", 21), ("La Nova Esquerra de l'Eixample", 19), ('El Gòtic', 15), ('El Raval', 15), ("L'Antiga Esquerra de l'Eixample", 10), ('La Sagrada Família', 10), ('Sants', 9), ('El Fort Pienc', 8), ('Sant Antoni', 8), ('Vila de Gràcia', 7), ('Sant Gervasi - Galvany', 7), ('Sant Pere - Santa Caterina i la Ribera', 6), ('El Baix Guinardó', 6), ('Les Corts', 4), ('Hostafrancs', 4), ('Sants - Badal', 4), ("El Camp de l'Arpa del Clot", 4), ('El Putxet i el Farró', 3), ('El Poble Sec - Parc de Montjuïc', 3), ('El Besòs', 3), ('Sant Gervasi - La Bonanova', 3), ('El Guinardó', 3), ('Vallcarca i els Penitents', 2), ('El Clot', 2), ('El Poblenou', 2), ('Navas', 2), ('La Barceloneta', 2), ('La Marina del Port', 2), ('La Vila Olímpica del Poblenou', 2), ('El Parc i la Llacuna del Poblenou', 2), ('La Font de la Guatlla', 2), ('El Congrés i els Indians', 1), ('Sarrià', 1), ('La Verneda i la Pau', 1), ('La Maternitat i Sant Ramon', 1), ('La Salut', 1), ('Pedralbes', 1), ('La Sagrera', 1), ('La Bordeta', 1), ("El Camp d'En Grassot i Gràcia Nova", 1), ('Can Baró', 1)]
# ---------------------------------------
# ---------------------------------------
# All rankings
# ---------------------------------------
#                                     Distance  Availability  Security
# El Parc i la Llacuna del Poblenou         41             2     164.0
# Fort Pienc                                15             8      93.0
# La Vila Olímpica del Poblenou             10             2     268.0
# El Poblenou                                7             2      81.0
# S. Pere, Santa Caterina, i la Rib.         4             6     134.0
# El Clot                                    2             2      93.0
# Sagrada Familia                            1            10      61.0
# ---------------------------------------
# ---------------------------------------
# Normalized ranking with final ranking:
# ---------------------------------------
#                                     Distance  Availability  Security   Ranking
# El Parc i la Llacuna del Poblenou      1.000          0.00  0.497585  4.502415
# Fort Pienc                             0.350          0.75  0.154589  3.845411
# Sagrada Familia                        0.000          1.00  0.000000  3.000000
# S. Pere, Santa Caterina, i la Rib.     0.075          0.50  0.352657  1.522343
# El Poblenou                            0.150          0.00  0.096618  0.653382
# La Vila Olímpica del Poblenou          0.225          0.00  1.000000  0.125000
# El Clot                                0.025          0.00  0.154589 -0.029589
# ---------------------------------------
# ---------------------------------------
# Final Ranking:
# ---------------------------------------
# 0- El Parc i la Llacuna del Poblenou
# 1- Fort Pienc
# 2- Sagrada Familia

# %%
from Map import draw_map

# %%
draw_map(lista, ranking.appartments_locations(lista), ranking.geofinder.get_location(), "BTS")
# Out:
# Map(basemap={'url': 'http://stamen-tiles-a.a.ssl.fastly.net/terrain/{z}/{x}/{y}.png', 'attribution': 'Map tile…

# %%
ranking.print_appartments(lista)
# Out:
# <h2><strong>El Parc i la Llacuna del Poblenou</strong></h2>
# <h4><strong>€550.0</strong></h4>
# <a>https://www.idealista.com/inmueble/81711284/</a>
# <h4><strong>€530.0</strong></h4>
# <a>https://www.idealista.com/inmueble/82721862/</a>
# <h2><strong>Fort Pienc</strong></h2>
# <h4><strong>€480.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85973236/</a>
# <h4><strong>€420.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85950819/</a>
# <h4><strong>€500.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85976256/</a>
# <h4><strong>€400.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85975486/</a>
# <h4><strong>€375.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85965796/</a>
# <h4><strong>€590.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85940095/</a>
# <h4><strong>€450.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85941893/</a>
# <h4><strong>€420.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85958224/</a>
# <h2><strong>Sagrada Familia</strong></h2>
# <h4><strong>€550.0</strong></h4>
# <a>https://www.idealista.com/inmueble/34363192/</a>
# <h4><strong>€400.0</strong></h4>
# <a>https://www.idealista.com/inmueble/38050904/</a>
# <h4><strong>€310.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85974773/</a>
# <h4><strong>€550.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85972615/</a>
# <h4><strong>€700.0</strong></h4>
# <a>https://www.idealista.com/inmueble/37513379/</a>
# <h4><strong>€420.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85974408/</a>
# <h4><strong>€350.0</strong></h4>
# <a>https://www.idealista.com/inmueble/83599403/</a>
# <h4><strong>€350.0</strong></h4>
# <a>https://www.idealista.com/inmueble/83726641/</a>
# <h4><strong>€400.0</strong></h4>
# <a>https://www.idealista.com/inmueble/36450362/</a>
# <h4><strong>€550.0</strong></h4>
# <a>https://www.idealista.com/inmueble/85717115/</a>
