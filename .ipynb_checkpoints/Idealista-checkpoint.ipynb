# %%
import pandas as pd
import requests
import base64
import json

# %%
with open('../accounts.json') as json_file:  
    data = json.load(json_file)

# %%
apikey = data['accounts']['Idealista']['apikey']
secret = data['accounts']['Idealista']['secret']
access_token = ''
token_type = ''

# %%
encoded_string = apikey + ":" + secret
encoded = base64.b64encode(encoded_string.encode())

# %%
authorization_header = 'Authorization'
grant_type = 'grant_type'
client_credentials = 'client_credentials'

# %%
r = requests.post('http://api.idealista.com/oauth/token',
             headers={authorization_header: 'Basic ' + encoded.decode()},
             params={grant_type:client_credentials})

# %%
access_token = r.json()['access_token']
token_type = r.json()['token_type']
search_authorization_value = token_type + ' ' + access_token

# %%
country = 'es'
operation = 'rent'
propertyType = 'homes' # 'bedrooms' is other option
center = '41.38621,2.15487', 
locale = 'en'
distance = 1300
locationId = '0-EU-ES-28' # ver qu es esto
maxItems = 50 # 50 as maximun allowed
maxPrice = 1000

# %%
params = {
    'locale':locale,
    'maxItems':maxItems,
    'operation':operation,
    'propertyType':propertyType,
    'apikey':apikey,
    'center' :center,
    'distance' :distance
}

# %%
home_search = requests.post('https://api.idealista.com/3.5/es/search',
                      headers={authorization_header: search_authorization_value},
                      params=params)

# %%
params[propertyType] = 'bedrooms'
beddrooms_search = requests.post('https://api.idealista.com/3.5/es/search',
                      headers={authorization_header: search_authorization_value},
                      params=params)

# %%
price = 'price'
propertyType = 'propertyType'
operation = 'operation'
rooms = 'rooms'
neighborhood = 'neighborhood'
latitude = 'latitude'
longitude = 'longitude'
distance = 'distance'
priceByArea = 'priceByArea'

# %%
homes = home_search.json().get('elementList')
bedrooms = beddrooms_search.json().get('elementList')

# %%
def add_item_to_dict(home, neighborhoods):
    item = { price:home[price],
             propertyType:home[propertyType],
             price:home[price],
             operation:home[operation],
             rooms:home[rooms],
             latitude:home[latitude],
             longitude:home[longitude],
             distance:home[distance],
             priceByArea:home[priceByArea]
            }

    if home[neighborhood] not in neighborhoods:
        neighborhoods[home[neighborhood]] = []
        
    neighborhoods[home[neighborhood]].append(item)

# %%
neighborhoods = {}
for home in homes:
    add_item_to_dict(home, neighborhoods)

# %%
dreta_eixample = next(iter(neighborhoods.values()))

# %%
dreta_eixample[0]
# Out:
# {'price': 650.0,
#  'propertyType': 'studio',
#  'operation': 'rent',
#  'rooms': 0,
#  'latitude': 41.3812105,
#  'longitude': 2.1651202,
#  'distance': '1019',
#  'priceByArea': 20.0}

# %%
for key in neighborhoods.keys():
    print(key)
# Out:
# El Raval
# Vila de Gràcia
# Sant Antoni
# L'Antiga Esquerra de l'Eixample
# La Nova Esquerra de l'Eixample
# El Gòtic
# La Dreta de l'Eixample
# Sant Gervasi - Galvany

# %%
def price_of_neighborhoods():
    neighs_price = {}
    for key in neighborhoods.keys():
        neighs_price[key] = price_per_neighborhood_homes(key)
    return neighs_price

# %%
def price_per_neighborhood(key):
    price_per_neighborhood = 0
    total_number_of_rooms = 0
    for appartment in neighborhoods[key]:
        if appartment[propertyType] == 'room':
            price_per_neighborhood += appartment[price]
            total_number_of_rooms += 1
        else:
            number_of_rooms = appartment[rooms] if appartment[rooms] > 0 else 1
            price_per_neighborhood += appartment[price] / number_of_rooms
            total_number_of_rooms += appartment[rooms]
    return (price_per_neighborhood / len(neighborhoods[key]), total_number_of_rooms)

# %%
def price_per_neighborhood_bedroom(key):
    price_per_neighborhood = 0
    total_number_of_rooms = 0
    for appartment in neighborhoods[key]:
        price_per_neighborhood += appartment[price]
        total_number_of_rooms += 1
    return (price_per_neighborhood / len(neighborhoods[key]), total_number_of_rooms)

# %%
price_of_neighborhoods()
# Out:
# {'El Raval': (941.25, 10),
#  'Vila de Gràcia': (925.0, 5),
#  'Sant Antoni': (516.5277777777778, 16),
#  "L'Antiga Esquerra de l'Eixample": (607.6388888888889, 33),
#  "La Nova Esquerra de l'Eixample": (458.452380952381, 41),
#  'El Gòtic': (950.0, 1),
#  "La Dreta de l'Eixample": (1272.5, 12),
#  'Sant Gervasi - Galvany': (1383.3333333333333, 5)}

# %%
# propertyType = 'homes' # 'bedrooms' is other option

# %%
beddrooms_search.json()
# Out:
# {'elementList': [{'propertyCode': '33966854',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/a2/34/53/634701475.jpg',
#    'numPhotos': 10,
#    'floor': '2',
#    'price': 660.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 240.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 4,
#    'address': 'gran via de les corts catalanes, 573',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3850888,
#    'longitude': 2.1620739,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/33966854/',
#    'distance': '613',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 10,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in gran via de les corts catalanes, 573'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '28515972',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c6/b5/d0/71226395.jpg',
#    'numPhotos': 4,
#    'floor': '3',
#    'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 80.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle Diputació, 130',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3824188,
#    'longitude': 2.1566316,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/28515972/',
#    'distance': '446',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle Diputació, 130'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84489039',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e5/67/07/640414971.jpg',
#    'numPhotos': 16,
#    'floor': '2',
#    'price': 440.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 75.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 1,
#    'address': 'Calle de Sepúlveda, 79',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3790802,
#    'longitude': 2.1568261,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84489039/',
#    'distance': '809',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Sepúlveda, 79'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '38850048',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/11/d8/f6/250531035.jpg',
#    'numPhotos': 9,
#    'floor': '1',
#    'price': 600.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle de València, 155',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3878941,
#    'longitude': 2.1567754,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/38850048/',
#    'distance': '245',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de València, 155'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84494599',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/7e/7e/ee/640516080.jpg',
#    'numPhotos': 8,
#    'floor': '2',
#    'price': 360.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 90.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': 'Calle de Rocafort, 33',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84494599/',
#    'distance': '1090',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Rocafort, 33'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84493039',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/4d/32/84/640491775.jpg',
#    'numPhotos': 11,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 70.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle del Tigre, 2',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84493039/',
#    'distance': '922',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'male',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle del Tigre, 2'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84492904',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/0a/55/ca/640489338.jpg',
#    'numPhotos': 7,
#    'floor': '6',
#    'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 110.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle del Comte Borrell, 238',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3871382,
#    'longitude': 2.1498626,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84492904/',
#    'distance': '430',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 5,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle del Comte Borrell, 238'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84492224',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/aa/32/2a/640475683.jpg',
#    'numPhotos': 9,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 70.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle del Tigre, 2',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84492224/',
#    'distance': '922',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle del Tigre, 2'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84491878',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/05/88/c8/640469003.jpg',
#    'numPhotos': 17,
#    'floor': '2',
#    'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle de Calàbria, 281',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3878689,
#    'longitude': 2.144006,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84491878/',
#    'distance': '924',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Calàbria, 281'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84491769',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ca/c9/b1/640466701.jpg',
#    'numPhotos': 8,
#    'floor': '3',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 75.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 1,
#    'address': 'Calle de Valldonzella, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3844048,
#    'longitude': 2.1660926,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84491769/',
#    'distance': '957',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle de Valldonzella, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84491655',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/37/26/55/640465887.jpg',
#    'numPhotos': 7,
#    'floor': '6',
#    'price': 310.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 80.0,
#    'exterior': False,
#    'rooms': 2,
#    'bathrooms': 2,
#    'address': 'Calle de Còrsega, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3840938,
#    'longitude': 2.1427356,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84491655/',
#    'distance': '1039',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Còrsega, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84491487',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e7/cd/6b/640462013.jpg',
#    'numPhotos': 17,
#    'floor': '2',
#    'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 2,
#    'address': 'Calle de Calàbria, 281',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3878689,
#    'longitude': 2.144006,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84491487/',
#    'distance': '924',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Calàbria, 281'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84490658',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/af/1b/58/640449266.jpg',
#    'numPhotos': 8,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 200.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 2,
#    'address': 'Calle de Muntaner, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84490658/',
#    'distance': '684',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 9,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 2.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Muntaner, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '26504314',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/52/81/29/42930262.jpg',
#    'numPhotos': 14,
#    'floor': 'en',
#    'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': "Calle d'Aragó, 4 -6",
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3798011,
#    'longitude': 2.1486126,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/26504314/',
#    'distance': '883',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': "Room in Calle d'Aragó, 4 -6"},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84489417',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/57/6b/7c/640424247.jpg',
#    'numPhotos': 17,
#    'floor': '2',
#    'price': 380.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 150.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': 'Calle de Balmes, 81  bis',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3908976,
#    'longitude': 2.1602804,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84489417/',
#    'distance': '689',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Balmes, 81  bis'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '39373994',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/53/3f/35/640412823.jpg',
#    'numPhotos': 9,
#    'floor': '1',
#    'price': 480.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 130.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': "Calle d'Enric Granados, 33",
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3894948,
#    'longitude': 2.1598965,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/39373994/',
#    'distance': '556',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': "Room in Calle d'Enric Granados, 33"},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84487954',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/34/c8/98/640390755.jpg',
#    'numPhotos': 8,
#    'floor': '6',
#    'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 110.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle del Comte Borrell, 238',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3871382,
#    'longitude': 2.1498626,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84487954/',
#    'distance': '430',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 5,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle del Comte Borrell, 238'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84492663',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/03/d7/65/640485022.jpg',
#    'numPhotos': 3,
#    'floor': '4',
#    'price': 370.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 60.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de València, 57',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3825187,
#    'longitude': 2.1495514,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84492663/',
#    'distance': '604',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de València, 57'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84421982',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/bd/93/12/638849397.jpg',
#    'numPhotos': 4,
#    'floor': '2',
#    'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 147.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 2,
#    'address': 'Calle de la Diputació, 47 popenkogmailcom',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84421982/',
#    'distance': '401',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 47 popenkogmailcom'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84415843',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f2/aa/fa/638567777.jpg',
#    'numPhotos': 4,
#    'floor': '2',
#    'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 147.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 2,
#    'address': 'Calle de la Diputació, 47 popenkogmailcom',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84415843/',
#    'distance': '401',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 47 popenkogmailcom'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84494485',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/7b/a5/65/640515915.jpg',
#    'numPhotos': 8,
#    'floor': '4',
#    'price': 510.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 181.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': "Calle d'Enric Granados, 151",
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3944015,
#    'longitude': 2.1533315,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84494485/',
#    'distance': '919',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': "Room in Calle d'Enric Granados, 151"},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84495152',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d9/75/40/640528218.jpg',
#    'numPhotos': 7,
#    'floor': '5',
#    'price': 370.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': 'Gran Via de les Corts Catalanes, 438',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3782345,
#    'longitude': 2.1537964,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84495152/',
#    'distance': '891',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Gran Via de les Corts Catalanes, 438'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84494818',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/0d/8d/b0/640521488.jpg',
#    'numPhotos': 11,
#    'floor': '5',
#    'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Calle de Mallorca, 35',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3829843,
#    'longitude': 2.1477486,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84494818/',
#    'distance': '693',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 5,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Mallorca, 35'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84477329',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c7/f9/0f/640166096.jpg',
#    'numPhotos': 12,
#    'floor': 'en',
#    'price': 775.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 45.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 1,
#    'address': 'Calle de Sant Vicenç, 26',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3815086,
#    'longitude': 2.1649601,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84477329/',
#    'distance': '990',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 17.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle de Sant Vicenç, 26'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84488159',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/0f/f1/1e/640397242.jpg',
#    'numPhotos': 10,
#    'floor': '7',
#    'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 20.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle de Rocafort, 191',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3832932,
#    'longitude': 2.1476921,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84488159/',
#    'distance': '680',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 20.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Rocafort, 191'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84495287',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/180/id.pro.es.image.master/50/d7/89/640529792.jpg',
#    'numPhotos': 6,
#    'floor': '5',
#    'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': "Calle Comte d'Urgell, 169",
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3878497,
#    'longitude': 2.1507277,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84495287/',
#    'distance': '390',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': "Room in Calle Comte d'Urgell, 169"},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84431100',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f9/9f/e7/639157248.jpg',
#    'numPhotos': 3,
#    'floor': 'en',
#    'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de la Diputació, 26',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3781634,
#    'longitude': 2.1509701,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84431100/',
#    'distance': '952',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 26'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84414436',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/af/95/cf/638545688.jpg',
#    'numPhotos': 6,
#    'floor': '4',
#    'price': 495.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 150.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Paseo de Gràcia, 50',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Dreta de l'Eixample",
#    'latitude': 41.3920533,
#    'longitude': 2.1657372,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84414436/',
#    'distance': '1115',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Dreta de l'Eixample, Barcelona",
#     'title': 'Room in Paseo de Gràcia, 50'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84414951',
#    'numPhotos': 0,
#    'floor': '4',
#    'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 1,
#    'address': 'Calle de París, 142',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3911734,
#    'longitude': 2.1503011,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84414951/',
#    'distance': '670',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de París, 142'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84479780',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d6/c1/84/640213947.jpg',
#    'numPhotos': 31,
#    'floor': 'en',
#    'price': 525.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle de Calàbria, 251',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3866434,
#    'longitude': 2.1456359,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84479780/',
#    'distance': '771',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Calàbria, 251'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '28927918',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/83/d4/fc/88498642.jpg',
#    'numPhotos': 34,
#    'floor': '1',
#    'price': 650.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 4,
#    'address': 'Avenida de Roma, 152',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3856944,
#    'longitude': 2.1558723,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/28927918/',
#    'distance': '101',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Avenida de Roma, 152'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '38907797',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/65/83/55/596787420.jpg',
#    'numPhotos': 38,
#    'floor': '4',
#    'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 175.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 4,
#    'address': 'Gran Via de les Corts Catalanes, 602',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Dreta de l'Eixample",
#    'latitude': 41.3867322,
#    'longitude': 2.1652773,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/38907797/',
#    'distance': '870',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 5,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Dreta de l'Eixample, Barcelona",
#     'title': 'Room in Gran Via de les Corts Catalanes, 602'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '38769363',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/20/fc/5a/614907413.jpg',
#    'numPhotos': 36,
#    'floor': 'bj',
#    'price': 690.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 175.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 5,
#    'address': 'Gran Via de les Corts Catalanes, 602',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Dreta de l'Eixample",
#    'latitude': 41.3867322,
#    'longitude': 2.1652773,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/38769363/',
#    'distance': '870',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 5,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Dreta de l'Eixample, Barcelona",
#     'title': 'Room in Gran Via de les Corts Catalanes, 602'},
#    'hasPlan': True,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84486711',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/22/8b/cb/640345492.jpg',
#    'numPhotos': 10,
#    'floor': '4',
#    'price': 590.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 90.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de la Diputació, 200',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3857425,
#    'longitude': 2.1610515,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84486711/',
#    'distance': '518',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'female',
#    'hasLift': False,
#    'isSmokingAllowed': True,
#    'priceByArea': 7.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 200'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '82083834',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/83/c7/d6/640277527.jpg',
#    'numPhotos': 14,
#    'floor': '5',
#    'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 85.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle del Consell de Cent, 82',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3797599,
#    'longitude': 2.1508576,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/82083834/',
#    'distance': '791',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle del Consell de Cent, 82'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84481717',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/9a/92/f5/640247310.jpg',
#    'numPhotos': 8,
#    'floor': '3',
#    'price': 520.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 140.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': "Calle Comte d'Urgell, 127",
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.385756,
#    'longitude': 2.1533315,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84481717/',
#    'distance': '137',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': "Room in Calle Comte d'Urgell, 127"},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84478348',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/dc/1f/5d/640186368.jpg',
#    'numPhotos': 8,
#    'floor': '2',
#    'price': 360.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 90.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': 'Calle de Rocafort, 33',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84478348/',
#    'distance': '1090',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Rocafort, 33'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84477620',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/81/9a/54/640171902.jpg',
#    'numPhotos': 10,
#    'floor': '2',
#    'price': 435.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 90.0,
#    'exterior': False,
#    'rooms': 6,
#    'bathrooms': 2,
#    'address': 'Calle de Rocafort, 33',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84477620/',
#    'distance': '1090',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Rocafort, 33'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84476992',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c7/df/ce/640159908.jpg',
#    'numPhotos': 12,
#    'floor': '1',
#    'price': 430.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 74.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de Calàbria, 109',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3799651,
#    'longitude': 2.1543917,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84476992/',
#    'distance': '695',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Calàbria, 109'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84475376',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/62/ff/70/640132364.jpg',
#    'numPhotos': 9,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 70.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle del Tigre, 2',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84475376/',
#    'distance': '922',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'male',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 5.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle del Tigre, 2'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84475167',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/38/31/c5/640129169.jpg',
#    'numPhotos': 7,
#    'floor': '2',
#    'price': 390.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 55.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de Vistalegre, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.378785,
#    'longitude': 2.1667545,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84475167/',
#    'distance': '1290',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 7.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle de Vistalegre, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84474616',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ca/18/c4/640126266.jpg',
#    'numPhotos': 8,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 200.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 2,
#    'address': 'Calle de Muntaner, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84474616/',
#    'distance': '684',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 9,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 2.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Muntaner, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84474463',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/22/69/6d/640125631.jpg',
#    'numPhotos': 8,
#    'floor': '1',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 200.0,
#    'exterior': False,
#    'rooms': 9,
#    'bathrooms': 2,
#    'address': 'Calle de Muntaner, 10',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84474463/',
#    'distance': '684',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 9,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 2.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Calle de Muntaner, 10'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '81196209',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/61/04/f0/572045240.jpg',
#    'numPhotos': 15,
#    'floor': '4',
#    'price': 420.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 100.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Avenida de Mistral, 65',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': 'Sant Antoni',
#    'latitude': 41.3757993,
#    'longitude': 2.1544785,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/81196209/',
#    'distance': '1158',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'Sant Antoni, Barcelona',
#     'title': 'Room in Avenida de Mistral, 65'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84418437',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1e/b4/26/638622959.jpg',
#    'numPhotos': 10,
#    'floor': '3',
#    'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 180.0,
#    'exterior': False,
#    'rooms': 5,
#    'bathrooms': 2,
#    'address': 'Calle dels Tallers, 6',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Ciutat Vella',
#    'country': 'es',
#    'neighborhood': 'El Raval',
#    'latitude': 41.3848623,
#    'longitude': 2.1697198,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84418437/',
#    'distance': '1247',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': 'El Raval, Barcelona',
#     'title': 'Room in Calle dels Tallers, 6'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84472932',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/90/id.pro.es.image.master/3b/97/02/640097745.jpg',
#    'numPhotos': 12,
#    'floor': '4',
#    'price': 700.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'roca fort, 244',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.386331,
#    'longitude': 2.144526,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84472932/',
#    'distance': '863',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 2,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 6.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in roca fort, 244'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84414487',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/90/id.pro.es.image.master/d3/51/5c/638546396.jpg',
#    'numPhotos': 22,
#    'floor': '5',
#    'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 115.0,
#    'exterior': False,
#    'rooms': 3,
#    'bathrooms': 1,
#    'address': 'Calle de Villarroel, 126',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3863863,
#    'longitude': 2.1553852,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84414487/',
#    'distance': '47',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'male',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 3.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de Villarroel, 126'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '84486607',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f5/7b/46/640343429.jpg',
#    'numPhotos': 4,
#    'floor': '2',
#    'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 147.0,
#    'exterior': False,
#    'rooms': 1,
#    'bathrooms': 2,
#    'address': 'Calle de la Diputació, 47 popenkogmailcom',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "L'Antiga Esquerra de l'Eixample",
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/84486607/',
#    'distance': '401',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 6,
#    'tenantGender': 'mixed',
#    'hasLift': False,
#    'isSmokingAllowed': False,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "L'Antiga Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 47 popenkogmailcom'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '83612953',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/32/c3/a2/621587949.jpg',
#    'numPhotos': 4,
#    'floor': '2',
#    'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 150.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 2,
#    'address': 'Calle de la Diputació, 115',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3825585,
#    'longitude': 2.1563183,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/83612953/',
#    'distance': '423',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 3,
#    'tenantGender': 'female',
#    'hasLift': True,
#    'isSmokingAllowed': False,
#    'priceByArea': 2.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle de la Diputació, 115'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False},
#   {'propertyCode': '27198502',
#    'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/99/d8/9d/116911320.jpg',
#    'numPhotos': 6,
#    'floor': '2',
#    'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'size': 120.0,
#    'exterior': False,
#    'rooms': 4,
#    'bathrooms': 1,
#    'address': 'Calle Calàbria, 114',
#    'province': 'Barcelona',
#    'municipality': 'Barcelona',
#    'district': 'Eixample',
#    'country': 'es',
#    'neighborhood': "La Nova Esquerra de l'Eixample",
#    'latitude': 41.3803183,
#    'longitude': 2.1544461,
#    'showAddress': True,
#    'url': 'https://www.idealista.com/inmueble/27198502/',
#    'distance': '656',
#    'hasVideo': False,
#    'newDevelopment': False,
#    'tenantNumber': 4,
#    'tenantGender': 'mixed',
#    'hasLift': True,
#    'isSmokingAllowed': True,
#    'priceByArea': 4.0,
#    'detailedType': {'typology': 'room'},
#    'suggestedTexts': {'subtitle': "La Nova Esquerra de l'Eixample, Barcelona",
#     'title': 'Room in Calle Calàbria, 114'},
#    'hasPlan': False,
#    'has3DTour': False,
#    'has360': False}],
#  'total': 987,
#  'totalPages': 20,
#  'actualPage': 1,
#  'itemsPerPage': 50,
#  'numPaginations': 0,
#  'hiddenResults': False,
#  'summary': ['Rent',
#   'Bedroom',
#   "subdistrict L'Antiga Esquerra de l'Eixample, Barcelona",
#   'All prices'],
#  'lowerRangePosition': 0,
#  'paginable': True,
#  'upperRangePosition': 50}

# %%
neighborhoods_bedrooms = {}
for bedroom in bedrooms:
    item = { price:bedroom[price],
             propertyType:bedroom[propertyType],
             price:bedroom[price],
             operation:bedroom[operation],
             rooms:bedroom[rooms],

             latitude:bedroom[latitude],
             longitude:bedroom[longitude],
             distance:bedroom[distance],
             priceByArea:bedroom[priceByArea]
            }

    if bedroom[neighborhood] not in neighborhoods_bedrooms:
        neighborhoods_bedrooms[bedroom[neighborhood]] = []
        
    neighborhoods_bedrooms[bedroom[neighborhood]].append(item)

# %%
neighborhoods_bedrooms
# Out:
# {"L'Antiga Esquerra de l'Eixample": [{'price': 660.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 9,
#    'latitude': 41.3850888,
#    'longitude': 2.1620739,
#    'distance': '613',
#    'priceByArea': 3.0},
#   {'price': 600.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3878941,
#    'longitude': 2.1567754,
#    'distance': '245',
#    'priceByArea': 5.0},
#   {'price': 380.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3908976,
#    'longitude': 2.1602804,
#    'distance': '689',
#    'priceByArea': 3.0},
#   {'price': 480.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3894948,
#    'longitude': 2.1598965,
#    'distance': '556',
#    'priceByArea': 4.0},
#   {'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 1,
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'distance': '401',
#    'priceByArea': 4.0},
#   {'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 1,
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'distance': '401',
#    'priceByArea': 4.0},
#   {'price': 510.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3944015,
#    'longitude': 2.1533315,
#    'distance': '919',
#    'priceByArea': 3.0},
#   {'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3911734,
#    'longitude': 2.1503011,
#    'distance': '670',
#    'priceByArea': 5.0},
#   {'price': 650.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3856944,
#    'longitude': 2.1558723,
#    'distance': '101',
#    'priceByArea': 5.0},
#   {'price': 590.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3857425,
#    'longitude': 2.1610515,
#    'distance': '518',
#    'priceByArea': 7.0},
#   {'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3863863,
#    'longitude': 2.1553852,
#    'distance': '47',
#    'priceByArea': 3.0},
#   {'price': 580.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 1,
#    'latitude': 41.3836771,
#    'longitude': 2.1583056,
#    'distance': '401',
#    'priceByArea': 4.0}],
#  "La Nova Esquerra de l'Eixample": [{'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3824188,
#    'longitude': 2.1566316,
#    'distance': '446',
#    'priceByArea': 5.0},
#   {'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3871382,
#    'longitude': 2.1498626,
#    'distance': '430',
#    'priceByArea': 4.0},
#   {'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3878689,
#    'longitude': 2.144006,
#    'distance': '924',
#    'priceByArea': 6.0},
#   {'price': 310.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 2,
#    'latitude': 41.3840938,
#    'longitude': 2.1427356,
#    'distance': '1039',
#    'priceByArea': 4.0},
#   {'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3878689,
#    'longitude': 2.144006,
#    'distance': '924',
#    'priceByArea': 6.0},
#   {'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3798011,
#    'longitude': 2.1486126,
#    'distance': '883',
#    'priceByArea': 5.0},
#   {'price': 490.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3871382,
#    'longitude': 2.1498626,
#    'distance': '430',
#    'priceByArea': 4.0},
#   {'price': 370.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3825187,
#    'longitude': 2.1495514,
#    'distance': '604',
#    'priceByArea': 6.0},
#   {'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3829843,
#    'longitude': 2.1477486,
#    'distance': '693',
#    'priceByArea': 4.0},
#   {'price': 400.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3832932,
#    'longitude': 2.1476921,
#    'distance': '680',
#    'priceByArea': 20.0},
#   {'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3878497,
#    'longitude': 2.1507277,
#    'distance': '390',
#    'priceByArea': 4.0},
#   {'price': 450.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3781634,
#    'longitude': 2.1509701,
#    'distance': '952',
#    'priceByArea': 5.0},
#   {'price': 525.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3866434,
#    'longitude': 2.1456359,
#    'distance': '771',
#    'priceByArea': 5.0},
#   {'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3797599,
#    'longitude': 2.1508576,
#    'distance': '791',
#    'priceByArea': 6.0},
#   {'price': 520.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.385756,
#    'longitude': 2.1533315,
#    'distance': '137',
#    'priceByArea': 4.0},
#   {'price': 430.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.3799651,
#    'longitude': 2.1543917,
#    'distance': '695',
#    'priceByArea': 6.0},
#   {'price': 700.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.386331,
#    'longitude': 2.144526,
#    'distance': '863',
#    'priceByArea': 6.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3825585,
#    'longitude': 2.1563183,
#    'distance': '423',
#    'priceByArea': 2.0},
#   {'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3803183,
#    'longitude': 2.1544461,
#    'distance': '656',
#    'priceByArea': 4.0}],
#  'Sant Antoni': [{'price': 440.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3790802,
#    'longitude': 2.1568261,
#    'distance': '809',
#    'priceByArea': 6.0},
#   {'price': 360.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'distance': '1090',
#    'priceByArea': 4.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 9,
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'distance': '684',
#    'priceByArea': 2.0},
#   {'price': 370.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3782345,
#    'longitude': 2.1537964,
#    'distance': '891',
#    'priceByArea': 3.0},
#   {'price': 360.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'distance': '1090',
#    'priceByArea': 4.0},
#   {'price': 435.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 6,
#    'latitude': 41.3765121,
#    'longitude': 2.1567902,
#    'distance': '1090',
#    'priceByArea': 5.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 9,
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'distance': '684',
#    'priceByArea': 2.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 9,
#    'latitude': 41.3843973,
#    'longitude': 2.1627051,
#    'distance': '684',
#    'priceByArea': 2.0},
#   {'price': 420.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3757993,
#    'longitude': 2.1544785,
#    'distance': '1158',
#    'priceByArea': 4.0}],
#  'El Raval': [{'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'distance': '922',
#    'priceByArea': 5.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'distance': '922',
#    'priceByArea': 5.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3844048,
#    'longitude': 2.1660926,
#    'distance': '957',
#    'priceByArea': 5.0},
#   {'price': 775.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 1,
#    'latitude': 41.3815086,
#    'longitude': 2.1649601,
#    'distance': '990',
#    'priceByArea': 17.0},
#   {'price': 350.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3830282,
#    'longitude': 2.1650841,
#    'distance': '922',
#    'priceByArea': 5.0},
#   {'price': 390.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 3,
#    'latitude': 41.378785,
#    'longitude': 2.1667545,
#    'distance': '1290',
#    'priceByArea': 7.0},
#   {'price': 500.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3848623,
#    'longitude': 2.1697198,
#    'distance': '1247',
#    'priceByArea': 3.0}],
#  "La Dreta de l'Eixample": [{'price': 495.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 4,
#    'latitude': 41.3920533,
#    'longitude': 2.1657372,
#    'distance': '1115',
#    'priceByArea': 3.0},
#   {'price': 550.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3867322,
#    'longitude': 2.1652773,
#    'distance': '870',
#    'priceByArea': 3.0},
#   {'price': 690.0,
#    'propertyType': 'room',
#    'operation': 'rent',
#    'rooms': 5,
#    'latitude': 41.3867322,
#    'longitude': 2.1652773,
#    'distance': '870',
#    'priceByArea': 4.0}]}

# %%
def price_of_neighborhoods():
    neighs_price = {}
    for key in neighborhoods.keys():
        neighs_price[key] = price_per_neighborhood(key)
    return neighs_price

# %%
def price_per_neighborhood(key):
    price_per_neighborhood = 0
    total_number_of_rooms = 0
    for appartment in neighborhoods[key]:
        number_of_rooms = appartment[rooms] if appartment[rooms] > 0 else 1
        price_per_neighborhood += appartment[price] / number_of_rooms
        total_number_of_rooms += appartment[rooms]
    return (price_per_neighborhood / len(neighborhoods[key]), total_number_of_rooms)
